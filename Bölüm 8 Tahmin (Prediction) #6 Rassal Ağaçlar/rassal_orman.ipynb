# %%
from IPython.display import Image
Image("1.PNG")

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
data = pd.read_csv("maaslar.csv")
X = data[["Egitim Seviyesi"]]
y = data[["maas"]]
# kaç tane decision tree çizileceği n_estimators
rfr = RandomForestRegressor(n_estimators=10,random_state=0)
mod = rfr.fit(X,y)
mod.predict([[11]])
# Out:
# <ipython-input-10-dfda054be50d>:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   mod = rfr.fit(X,y)
# array([42500.])

# %%
data
# Out:
#               unvan  Egitim Seviyesi   maas
# 0             Cayci                1   2250
# 1          Sekreter                2   2500
# 2  Uzman Yardimcisi                3   3000
# 3             Uzman                4   4000
# 4  Proje Yoneticisi                5   5500
# 5               Sef                6   7500
# 6             Mudur                7  10000
# 7          Direktor                8  15000
# 8           C-level                9  25000
# 9               CEO               10  50000

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)
plt.plot(X,mod.predict(X))
